# %%
! pip install scikit-surprise -i http://pypi.douban.com/simple --trusted-host pypi.douban.com
# Out:
# Looking in indexes: http://pypi.douban.com/simple
# ...
#     100% |████████████████████████████████| 3.3MB 14.9MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 286kB 803kB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for scikit-surprise ... done
#   Stored in directory: /Users/maoyuyang/Library/Caches/pip/wheels/64/a3/ed/ba5b38cbc4e3b3c9525005a483f7c2169aa8d37ce405cae02d
# Successfully built scikit-surprise
# ...

# %%
import pandas as pd
from surprise import Reader, Dataset

ratings_csv = pd.read_csv('./data/ratings.csv')

ratings_csv = ratings_csv.drop(['timestamp'], axis=1)

ratings_csv
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# 5            1       70     3.0
# 6            1      101     5.0
# 7            1      110     4.0
# 8            1      151     5.0
# 9            1      157     5.0
# 10           1      163     5.0
# 11           1      216     5.0
# 12           1      223     3.0
# 13           1      231     5.0
# 14           1      235     4.0
# 15           1      260     5.0
# 16           1      296     3.0
# 17           1      316     3.0
# 18           1      333     5.0
# 19           1      349     4.0
# 20           1      356     4.0
# 21           1      362     5.0
# 22           1      367     4.0
# 23           1      423     3.0
# 24           1      441     4.0
# 25           1      457     5.0
# 26           1      480     4.0
# 27           1      500     3.0
# ...

# %%
reader = Reader(rating_scale=(0.5, 5.0))

data = Dataset.load_from_df(ratings_csv[['userId', 'movieId', 'rating']], reader)

# %%
ratings_csv.describe()
# Out:
#               userId        movieId         rating
# count  100836.000000  100836.000000  100836.000000
# mean      326.127564   19435.295718       3.501557
# std       182.618491   35530.987199       1.042529
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8122.000000       4.000000
# max       610.000000  193609.000000       5.000000

# %%
from surprise import SVD
from surprise.model_selection import cross_validate

algo = SVD()

# 交叉验证，得出SVD模型的RMSE
cross_validate(algo, data, measures=['RMSE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8728  0.8791  0.8769  0.8778  0.8652  0.8744  0.0051
# Fit time          8.83    8.31    8.49    8.70    8.52    8.57    0.18
# Test time         0.26    0.27    0.23    0.25    0.26    0.25    0.01
# {'test_rmse': array([0.87276586, 0.87910916, 0.87693223, 0.87778487, 0.86515835]),
#  'fit_time': (8.829239130020142,
#   8.308080196380615,
#   8.489455938339233,
#   8.700991868972778,
#   8.522536993026733),
#  'test_time': (0.2555389404296875,
#   0.2653062343597412,
#   0.2345900535583496,
#   0.2519369125366211,
#   0.2552809715270996)}
